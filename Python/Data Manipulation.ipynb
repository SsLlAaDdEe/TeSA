# %% [markdown]
# ### Python Module

# %% [markdown]
# * python file that contains executables (functions)
# * A module is like a macro of python; it stores variables, functions e.t.c., that can be used
# * Related functions in a file
# * It can be reused by 'importing' the module

# %% [markdown]
# #### Built-in Modules

# %%
import datetime

# %%
import math as m

# %%
#math.sqrt(4)

# %%
m.sqrt(9)
# Out:
# 3.0

# %%
m.sqrt(16)
# Out:
# 4.0

# %%
import os

# %%
import even

# %%
even.greeting()
# Out:
# hello world!

# %%
pwd
# Out:
# 'c:\\Users\\vicky\\OneDrive\\Documents\\TeSA\\Python'

# %%
even.even(79)
# Out:
# 79 is an odd number

# %% [markdown]
# ### Working with file

# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\vicky\\OneDrive\\Documents\\TeSA\\Python'

# %%
df1 = pd.read_csv("Bank_Churn.csv")

# %%
df1.head(3)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
#
#    Exited
# 0       1
# 1       0
# 2       1

# %%
df = pd.read_csv("Bank_Churn.csv")

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
#pip install openpyxl

# %%
df4 = pd.read_excel("Bank_Churn_Messy.xlsx")

# %%
df4.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619       FRA  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    French  Female  42.0       8
# 3    15701354      Boni          699       FRA  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#   EstimatedSalary
# 0      €101348.88
# 1      €112542.58
# 2      €113931.57
# 3       €93826.63
# 4        €79084.1

# %%
df
# Out:
#       CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0       15634602   Hargrave          619    France  Female   42       2
# 1       15647311       Hill          608     Spain  Female   41       1
# 2       15619304       Onio          502    France  Female   42       8
# 3       15701354       Boni          699    France  Female   39       1
# 4       15737888   Mitchell          850     Spain  Female   43       2
# ...          ...        ...          ...       ...     ...  ...     ...
# 9995    15606229   Obijiaku          771    France    Male   39       5
# 9996    15569892  Johnstone          516    France    Male   35      10
# 9997    15584532        Liu          709    France  Female   36       7
# 9998    15682355  Sabbatini          772   Germany    Male   42       3
# 9999    15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %% [markdown]
# * Dataframe is a 2-dimensional, tabular data structre. Like Excel Spreadsheet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
df['CustomerId'] = df['CustomerId'].astype(str)

# %%
df['IsActiveMember'] = df['IsActiveMember'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  object
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  object
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 1015.8+ KB

# %%
pd.to_numeric(df["CustomerId"])
# Out:
# 0       15634602
# 1       15647311
# 2       15619304
# 3       15701354
# 4       15737888
#           ...
# 9995    15606229
# 9996    15569892
# 9997    15584532
# 9998    15682355
# 9999    15628319
# Name: CustomerId, Length: 10000, dtype: int64

# %%
bless_df = df[['CustomerId', 'Gender', 'Exited']]

# %%
bless_df
# Out:
#      CustomerId  Gender  Exited
# 0      15634602  Female       1
# 1      15647311  Female       0
# 2      15619304  Female       1
# 3      15701354  Female       0
# 4      15737888  Female       0
# ...         ...     ...     ...
# 9995   15606229    Male       0
# 9996   15569892    Male       0
# 9997   15584532  Female       1
# 9998   15682355    Male       1
# 9999   15628319  Female       0
#
# [10000 rows x 3 columns]

# %%
df
# Out:
#      CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0      15634602   Hargrave          619    France  Female   42       2
# 1      15647311       Hill          608     Spain  Female   41       1
# 2      15619304       Onio          502    France  Female   42       8
# 3      15701354       Boni          699    France  Female   39       1
# 4      15737888   Mitchell          850     Spain  Female   43       2
# ...         ...        ...          ...       ...     ...  ...     ...
# 9995   15606229   Obijiaku          771    France    Male   39       5
# 9996   15569892  Johnstone          516    France    Male   35      10
# 9997   15584532        Liu          709    France  Female   36       7
# 9998   15682355  Sabbatini          772   Germany    Male   42       3
# 9999   15628319     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard IsActiveMember  EstimatedSalary  \
# ...

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  EstimatedSalary        Exited
# count  10000.00000     10000.000000  10000.000000
# mean       0.70550    100090.239881      0.203700
# std        0.45584     57510.492818      0.402769
# min        0.00000        11.580000      0.000000
# ...

# %%
df = df4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Surname          9998 non-null   object
#  2   CreditScore      10001 non-null  int64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              9998 non-null   float64
#  6   Tenure           10001 non-null  int64
#  7   EstimatedSalary  10001 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 625.2+ KB

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            3
# CreditScore        0
# Geography          0
# Gender             0
# Age                3
# Tenure             0
# EstimatedSalary    0
# dtype: int64

# %%
df[df.isnull().any(axis = 1)]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 28      15728693     NaN          574   Germany  Female  NaN       3
# 121     15580203     NaN          674     Spain    Male  NaN       6
# 9389    15756954     NaN          538    France  Female  NaN       2
#
#      EstimatedSalary
# 28          -€999999
# 121         -€999999
# 9389        -€999999

# %%
df[df.isnull().any(axis = 1)]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 28      15728693     NaN          574   Germany  Female  NaN       3
# 121     15580203     NaN          674     Spain    Male  NaN       6
# 9389    15756954     NaN          538    France  Female  NaN       2
#
#      EstimatedSalary
# 28          -€999999
# 121         -€999999
# 9389        -€999999

# %%
df[df['Age'].isnull()]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 28      15728693     NaN          574   Germany  Female  NaN       3
# 121     15580203     NaN          674     Spain    Male  NaN       6
# 9389    15756954     NaN          538    France  Female  NaN       2
#
#      EstimatedSalary
# 28          -€999999
# 121         -€999999
# 9389        -€999999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10001 non-null  int64
#  1   Surname          9998 non-null   object
#  2   CreditScore      10001 non-null  int64
#  3   Geography        10001 non-null  object
#  4   Gender           10001 non-null  object
#  5   Age              9998 non-null   float64
#  6   Tenure           10001 non-null  int64
#  7   EstimatedSalary  10001 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 625.2+ KB

# %%
amt = '$999999'

# %%
type(amt)
# Out:
# str

# %%
amt.replace('$', '')
# Out:
# '999999'

# %%
amt = amt.replace('$', '')

# %%
amt = int(amt)

# %%
amt
# Out:
# 999999

# %%
df['EstimatedSalary'].head()
# Out:
# 0    €101348.88
# 1    €112542.58
# 2    €113931.57
# 3     €93826.63
# 4      €79084.1
# Name: EstimatedSalary, dtype: object

# %%
def _data(x):
    val = x.replace("€", '')
    return val

# %%
df['EstimatedSalary'].apply(_data)
# Out:
# 0        101348.88
# 1        112542.58
# 2        113931.57
# 3         93826.63
# 4          79084.1
#            ...
# 9996     101699.77
# 9997      42085.58
# 9998      92888.52
# 9999      38190.78
# 10000     38190.78
# Name: EstimatedSalary, Length: 10001, dtype: object

# %%
df['EstimatedSalary'] = df['EstimatedSalary'].apply(_data)

# %%
df
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave          619       FRA  Female  42.0       2
# 1        15647311       Hill          608     Spain  Female  41.0       1
# 2        15619304       Onio          502    French  Female  42.0       8
# 3        15701354       Boni          699       FRA  Female  39.0       1
# 4        15737888   Mitchell          850     Spain  Female  43.0       2
# ...           ...        ...          ...       ...     ...   ...     ...
# 9996     15569892  Johnstone          516    French    Male  35.0      10
# 9997     15584532        Liu          709       FRA  Female  36.0       7
# 9998     15682355  Sabbatini          772   Germany    Male  42.0       3
# 9999     15628319     Walker          792    French  Female  28.0       4
# 10000    15628319     Walker          792    French  Female  28.0       4
#
#       EstimatedSalary
# 0           101348.88
# 1           112542.58
# ...

# %%
df['EstimatedSalary'] = pd.to_numeric(df['EstimatedSalary'])

# %%
df
# Out:
#        CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave          619       FRA  Female  42.0       2
# 1        15647311       Hill          608     Spain  Female  41.0       1
# 2        15619304       Onio          502    French  Female  42.0       8
# 3        15701354       Boni          699       FRA  Female  39.0       1
# 4        15737888   Mitchell          850     Spain  Female  43.0       2
# ...           ...        ...          ...       ...     ...   ...     ...
# 9996     15569892  Johnstone          516    French    Male  35.0      10
# 9997     15584532        Liu          709       FRA  Female  36.0       7
# 9998     15682355  Sabbatini          772   Germany    Male  42.0       3
# 9999     15628319     Walker          792    French  Female  28.0       4
# 10000    15628319     Walker          792    French  Female  28.0       4
#
#        EstimatedSalary
# 0            101348.88
# 1            112542.58
# ...

# %%
df.rename(columns={"EstimatedSalary": "Estimated Salary(€)", "CreditScore" : "Credit Score"})
# Out:
#        CustomerId    Surname  Credit Score Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave           619       FRA  Female  42.0       2
# 1        15647311       Hill           608     Spain  Female  41.0       1
# 2        15619304       Onio           502    French  Female  42.0       8
# 3        15701354       Boni           699       FRA  Female  39.0       1
# 4        15737888   Mitchell           850     Spain  Female  43.0       2
# ...           ...        ...           ...       ...     ...   ...     ...
# 9996     15569892  Johnstone           516    French    Male  35.0      10
# 9997     15584532        Liu           709       FRA  Female  36.0       7
# 9998     15682355  Sabbatini           772   Germany    Male  42.0       3
# 9999     15628319     Walker           792    French  Female  28.0       4
# 10000    15628319     Walker           792    French  Female  28.0       4
#
#        Estimated Salary(€)
# 0                101348.88
# ...

# %%
df = df.rename(columns={"EstimatedSalary": "Estimated Salary(€)", "CreditScore" : "Credit Score"})

# %%
df
# Out:
#        CustomerId    Surname  Credit Score Geography  Gender   Age  Tenure  \
# 0        15634602   Hargrave           619       FRA  Female  42.0       2
# 1        15647311       Hill           608     Spain  Female  41.0       1
# 2        15619304       Onio           502    French  Female  42.0       8
# 3        15701354       Boni           699       FRA  Female  39.0       1
# 4        15737888   Mitchell           850     Spain  Female  43.0       2
# ...           ...        ...           ...       ...     ...   ...     ...
# 9996     15569892  Johnstone           516    French    Male  35.0      10
# 9997     15584532        Liu           709       FRA  Female  36.0       7
# 9998     15682355  Sabbatini           772   Germany    Male  42.0       3
# 9999     15628319     Walker           792    French  Female  28.0       4
# 10000    15628319     Walker           792    French  Female  28.0       4
#
#        Estimated Salary(€)
# 0                101348.88
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerId           10001 non-null  int64
#  1   Surname              9998 non-null   object
#  2   Credit Score         10001 non-null  int64
#  3   Geography            10001 non-null  object
#  4   Gender               10001 non-null  object
#  5   Age                  9998 non-null   float64
#  6   Tenure               10001 non-null  int64
#  7   Estimated Salary(€)  10001 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 625.2+ KB

# %%
df['CustomerId'] = df['CustomerId'].astype(str)

# %%
df.describe()
# Out:
#        Credit Score          Age        Tenure  Estimated Salary(€)
# count  10001.000000  9998.000000  10001.000000         10001.000000
# mean     650.542946    38.920984      5.012699         99756.038763
# std       96.658818    10.489116      2.892047         60583.962827
# min      350.000000    18.000000      0.000000       -999999.000000
# 25%      584.000000    32.000000      3.000000         50908.480000
# 50%      652.000000    37.000000      5.000000        100183.050000
# 75%      718.000000    44.000000      7.000000        149384.430000
# max      850.000000    92.000000     10.000000        199992.480000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerId           10001 non-null  object
#  1   Surname              9998 non-null   object
#  2   Credit Score         10001 non-null  int64
#  3   Geography            10001 non-null  object
#  4   Gender               10001 non-null  object
#  5   Age                  9998 non-null   float64
#  6   Tenure               10001 non-null  int64
#  7   Estimated Salary(€)  10001 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 625.2+ KB

# %%
df.head()
# Out:
#   CustomerId   Surname  Credit Score Geography  Gender   Age  Tenure  \
# 0   15634602  Hargrave           619       FRA  Female  42.0       2
# 1   15647311      Hill           608     Spain  Female  41.0       1
# 2   15619304      Onio           502    French  Female  42.0       8
# 3   15701354      Boni           699       FRA  Female  39.0       1
# 4   15737888  Mitchell           850     Spain  Female  43.0       2
#
#    Estimated Salary(€)
# 0            101348.88
# 1            112542.58
# 2            113931.57
# 3             93826.63
# 4             79084.10

# %%
df.ffill(inplace=True)

# %%
df[df.duplicated()]
# Out:
#       CustomerId Surname  Credit Score Geography  Gender   Age  Tenure  \
# 10000   15628319  Walker           792    French  Female  28.0       4
#
#        Estimated Salary(€)
# 10000             38190.78

# %%
df.tail()
# Out:
#       CustomerId    Surname  Credit Score Geography  Gender   Age  Tenure  \
# 9996    15569892  Johnstone           516    French    Male  35.0      10
# 9997    15584532        Liu           709       FRA  Female  36.0       7
# 9998    15682355  Sabbatini           772   Germany    Male  42.0       3
# 9999    15628319     Walker           792    French  Female  28.0       4
# 10000   15628319     Walker           792    French  Female  28.0       4
#
#        Estimated Salary(€)
# 9996             101699.77
# 9997              42085.58
# 9998              92888.52
# 9999              38190.78
# 10000             38190.78

# %%
df.shape
# Out:
# (10001, 8)

# %%
df.shape[0]
# Out:
# 10001

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerId           10000 non-null  object
#  1   Surname              10000 non-null  object
#  2   Credit Score         10000 non-null  int64
#  3   Geography            10000 non-null  object
#  4   Gender               10000 non-null  object
#  5   Age                  10000 non-null  float64
#  6   Tenure               10000 non-null  int64
#  7   Estimated Salary(€)  10000 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 703.1+ KB

# %%
df["Geography"].replace("French", "France", inplace=True)
# Out:
# C:\Users\vicky\AppData\Local\Temp\ipykernel_28632\539286146.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Geography"].replace("French", "France", inplace=True)

# %%
df["Geography"].value_counts()
# Out:
# Geography
# France     3396
# Germany    2509
# Spain      2477
# FRA        1618
# Name: count, dtype: int64

# %%
df["Geography"].replace("FRA", "France", inplace=True)
# Out:
# C:\Users\vicky\AppData\Local\Temp\ipykernel_28632\305318789.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Geography"].replace("FRA", "France", inplace=True)

# %%
df.head()
# Out:
#   CustomerId   Surname  Credit Score Geography  Gender   Age  Tenure  \
# 0   15634602  Hargrave           619    France  Female  42.0       2
# 1   15647311      Hill           608     Spain  Female  41.0       1
# 2   15619304      Onio           502    France  Female  42.0       8
# 3   15701354      Boni           699    France  Female  39.0       1
# 4   15737888  Mitchell           850     Spain  Female  43.0       2
#
#    Estimated Salary(€)
# 0            101348.88
# 1            112542.58
# 2            113931.57
# 3             93826.63
# 4             79084.10

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], bins=10);

# %%
plt.barh(df['Geography'].value_counts().index, df['Geography'].value_counts());

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerId           10000 non-null  object
#  1   Surname              10000 non-null  object
#  2   Credit Score         10000 non-null  int64
#  3   Geography            10000 non-null  object
#  4   Gender               10000 non-null  object
#  5   Age                  10000 non-null  float64
#  6   Tenure               10000 non-null  int64
#  7   Estimated Salary(€)  10000 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 703.1+ KB

# %%
df["Age"] = df["Age"].astype(int)

# %%
df.head()
# Out:
#   CustomerId   Surname  Credit Score Geography  Gender  Age  Tenure  \
# 0   15634602  Hargrave           619    France  Female   42       2
# 1   15647311      Hill           608     Spain  Female   41       1
# 2   15619304      Onio           502    France  Female   42       8
# 3   15701354      Boni           699    France  Female   39       1
# 4   15737888  Mitchell           850     Spain  Female   43       2
#
#    Estimated Salary(€)
# 0            101348.88
# 1            112542.58
# 2            113931.57
# 3             93826.63
# 4             79084.10

# %%
df.describe()
# Out:
#        Credit Score           Age        Tenure  Estimated Salary(€)
# count  10000.000000  10000.000000  10000.000000         10000.000000
# mean     650.528800     38.922100      5.012800         99762.195289
# std       96.653299     10.487737      2.892174         60583.863580
# min      350.000000     18.000000      0.000000       -999999.000000
# 25%      584.000000     32.000000      3.000000         50910.677500
# 50%      652.000000     37.000000      5.000000        100191.725000
# 75%      718.000000     44.000000      7.000000        149388.247500
# max      850.000000     92.000000     10.000000        199992.480000

# %%
plt.boxplot(df['Estimated Salary(€)']);

# %%
df.groupby('Geography')['Estimated Salary(€)'].mean()
# Out:
# pandas.core.series.Series
