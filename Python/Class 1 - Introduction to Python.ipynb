# %% [markdown]
# **Python Structure**
# #### Python Shortcuts
# ### Python Shortcuts
# ## Python Shortcuts
# # Python Shortcuts
# * Esc + M = To change cell style to Markdown
# * Esc + Y = To change cell style to Code
# * Esc + A = To add a cell above the selected cell
# * Esc + B = To add a cell below the selected cell
# * Esc + DD = To delete a cell
# * Shift + Enter = To execute a cell

# %% [markdown]
# ## Variables
# ### Naming Convention
# * It's best to start with a small letter
# *

# %% [markdown]
# ## Python Day 2

# %%
def bles:
# Out:
#   Cell In[1], line 1
#     def bles:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Data Structures
# * Lists
# * Dictionaries
# * Tuples
# * Sets

# %%
# Lists
my_list = [1, "Emmanuel", 1.0]
my_list
# Out:
# [1, 'Emmanuel', 1.0]

# %%
my_list.append(3)

# %%
my_list
# Out:
# [1, 'Emmanuel', 1.0, 3]

# %%
my_list[1] = 55
my_list
# Out:
# [1, 55, 1.0, 3]

# %%
my_list[1:3] = ["Vic", "Tory"]
my_list
# Out:
# [1, 'Vic', 'Tory', 3]
