# %% [markdown]
# ## Python

# %% [markdown]
# #### Loop Control Statements

# %% [markdown]
# ##### **Pass**

# %%
def student():
    pass

# %%
student()

# %%
def student_():

# %%
for i in range(5):
    pass

# %%
for i in range(5):
    print (i**2)

# %%
x = 7
if x > 5:
    pass
else:
    print("x is 5 or less")

# %%
x = 7
if x > 5:
    
else:
    print("x is 5 or less")

# %%
x = 3
if x > 5:
    pass
else:
    print("x is 5 or less")

# %% [markdown]
# ##### **continue**

# %%
list(range(7))

# %%
for i in range(7):
    if i==2:
        continue
    print(i)

# %%
for i in range(7):
    print(i)

# %%
num = [-8, 0, 4, -1]

# %%
for i in num:
    if i < 0:
        continue
    print(i)

# %%
name = ["Ade", "Shola", "Ayo", "Adeniyi", "Olaoluwa"]

# %%
for i in name:
    if i[0]=="A":
        continue
    print(i)

# %%
x = 0
while x < 7:
    x += 1
    if x == 3:
        continue
    print(x)

# %%
x = 0
while x < 7:
    print(x)
    x += 1
    if x == 3:
        continue

# %% [markdown]
# ##### **break**

# %%
for i in range(7):
    if i==2:
        break
    print(i)

# %%
num = [-8, 0, 4, -1]

# %%
for i in num:
    if i < 0:
        break
    print(i)

# %%
_num = [0, -8, 4, -1]

# %%
for i in _num:
    if i < 0:
        break
    print(i)

# %%
x = 0
while x < 7:
    x += 1
    if x == 3:
        break
    print(x)

# %%
x = 0
while x < 7:
    x += 1
    if x == 3:
        continue
    print(x)

# %%
x = 0
while x < 7:
    if x == 3:
        x += 1
        continue
    print(x)
    x += 1

# %% [markdown]
# equal to : ==
# assignment : =

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Built-in Functions
# * They are functions that are predefined in Python
# * It can be used without needing to import any library
# * You don't need to define they yourself
# * They are also Python's standard namespace i.e you can call them directly in your code

# %%
print()

# %%
print("Blessing is an Educator \nShe teaches Data Analytics")

# %% [markdown]
# * Arguments are values you pass into a function to call it

# %%
list(range())

# %%
range()

# %%
"Blessing".

# %%
x = [1,2,3,4,5]

# %%
x.append([5, 6])

# %%
x

# %%
x.extend([1,4,5])

# %%
x

# %%
x.extend((6,7))

# %%
x

# %%
x.extend(["Blessing", "Kamara"])

# %%
x

# %%
x.pop()

# %%
x.pop(-3)

# %%
x

# %%
x.count('Blessing')

# %%
x.pop()

# %%
x.sort()

# %%
x

# %%
x.sort(reverse=True)

# %%
x

# %%
x.pop(14)

# %% [markdown]
# #### User-defined Function

# %% [markdown]
# * Is a function that you create yourself
# * Using the def keyword

# %% [raw]
# def #function_name():
#     logic

# %%
def greeting():
    """
    This function is used to welcome a person!
    """
    print("Hello world!")

# %%
greeting()

# %%
greeting()

# %%
print("Hello World!")

# %%
greeting()

# %%
def add(value, value_):
    """
    This function takes in two numeric values and add them.
    """
    x = float(value) + float(value_)
    print (int(x))

# %%
add(2, 9)

# %%
add (7.8, 3)

# %%
print("""Hello
My name is
Blessing
""")

# %%
print("Hello \nMy name is \nBlessing")

# %%
pwd

# %% [markdown]
# ### Python Module

# %% [markdown]
# * python file that contains executables (functions)
# * A module is like a macro of python; it stores variables, functions e.t.c., that can be used
# * Related functions in a file
# * It can be reused by 'importing' the module

# %% [markdown]
# #### Built-in Modules

# %%
import math as m

# %%
import even

# %%
m.sqrt(4)
# Out:
# 2.0

# %%
m.sqrt(9)
# Out:
# 3.0

# %%
m.sqrt(16)
# Out:
# 4.0

# %%
even.greeting()
# Out:
# hello world!

# %%
pwd
# Out:
# 'c:\\Users\\vicky\\OneDrive\\Documents\\TeSA\\Python'

# %%
even.even(79)
# Out:
# 79 is an odd number

# %%
even.even(80)
# Out:
# 80 is an even number

# %% [markdown]
# ### Working with Pandas

# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\vicky\\OneDrive\\Documents\\TeSA\\Python'

# %%
df = pd.read_csv("Bank_Churn.csv")

# %%
df.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_excel("Bank_Churn_Messy.xlsx")

# %%
df1.head()
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave          619       FRA  Female  42.0       2
# 1    15647311      Hill          608     Spain  Female  41.0       1
# 2    15619304      Onio          502    French  Female  42.0       8
# 3    15701354      Boni          699       FRA  Female  39.0       1
# 4    15737888  Mitchell          850     Spain  Female  43.0       2
#
#   EstimatedSalary
# 0      €101348.88
# 1      €112542.58
# 2      €113931.57
# 3       €93826.63
# 4        €79084.1

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# CustomerId         0
# Surname            3
# CreditScore        0
# Geography          0
# Gender             0
# Age                3
# Tenure             0
# EstimatedSalary    0
# dtype: int64

# %%
df1["Gender"].head()
# Out:
# 0    Female
# 1    Female
# 2    Female
# 3    Female
# 4    Female
# Name: Gender, dtype: object

# %%
df1["Age"].mean()
# Out:
# np.float64(38.92098419683937)

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1["CreditScore"].mean()
# Out:
# np.float64(650.5429457054295)

# %%
pip install matplotlib
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting matplotlib
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 8.1/8.1 MB 914.7 kB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 2.3/2.3 MB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 7.0/7.0 MB 1.6 MB/s eta 0:00:00
# ...
#
# ...
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000297A40259C0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/2d/99/8325b3386b479b1d182ab1a7fd588fd393ff00a99dc04b7cf7d06668cf0f/matplotlib-3.10.6-cp310-cp310-win_amd64.whl.metadata
# ...

# %%
import matplotlib.pyplot as plt

# %%
df1["Age"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1015.8+ KB

# %%
df["CustomerId"] = df["CustomerId"].astype("string")
df["IsActiveMember"] = df["IsActiveMember"].astype("string")

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  EstimatedSalary        Exited
# count  10000.00000     10000.000000  10000.000000
# mean       0.70550    100090.239881      0.203700
# std        0.45584     57510.492818      0.402769
# min        0.00000        11.580000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  string
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  string
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(6), object(3), string(2)
# memory usage: 1015.8+ KB

# %%
df1.isnull().sum()
# Out:
# CustomerId         0
# Surname            3
# CreditScore        0
# Geography          0
# Gender             0
# Age                3
# Tenure             0
# EstimatedSalary    0
# dtype: int64

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#       CustomerId Surname  CreditScore Geography  Gender  Age  Tenure  \
# 28      15728693     NaN          574   Germany  Female  NaN       3
# 121     15580203     NaN          674     Spain    Male  NaN       6
# 9389    15756954     NaN          538    France  Female  NaN       2
#
#      EstimatedSalary
# 28           -999999
# 121          -999999
# 9389         -999999

# %%
df1["EstimatedSalary"] = df1["EstimatedSalary"].astype("string")

# %%
df1["EstimatedSalary"].head()
# Out:
# 0    €101348.88
# 1    €112542.58
# 2    €113931.57
# 3     €93826.63
# 4      €79084.1
# Name: EstimatedSalary, dtype: string

# %%
def _data(x):
    val = x.replace("€", "")
    return val

# %%
df1["EstimatedSalary"] = df1["EstimatedSalary"].apply(_data)

# %%
df1 = df1.rename(columns={"EstimatedSalary": "Estimated Salary(€)", "CreditScore": "Credit Score"})

# %%
df1["Estimated Salary(€)"] = pd.to_numeric(df1["Estimated Salary(€)"])

# %%
df1.head()
# Out:
#    CustomerId   Surname  Credit Score Geography  Gender   Age  Tenure  \
# 0    15634602  Hargrave           619       FRA  Female  42.0       2
# 1    15647311      Hill           608     Spain  Female  41.0       1
# 2    15619304      Onio           502    French  Female  42.0       8
# 3    15701354      Boni           699       FRA  Female  39.0       1
# 4    15737888  Mitchell           850     Spain  Female  43.0       2
#
#   Estimated Salary(€)
# 0           101348.88
# 1           112542.58
# 2           113931.57
# 3            93826.63
# 4             79084.1

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10001 entries, 0 to 10000
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CustomerId           10001 non-null  int64
#  1   Surname              9998 non-null   object
#  2   Credit Score         10001 non-null  int64
#  3   Geography            10001 non-null  object
#  4   Gender               10001 non-null  object
#  5   Age                  9998 non-null   float64
#  6   Tenure               10001 non-null  int64
#  7   Estimated Salary(€)  10001 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 625.2+ KB

# %%
df1.describe()
# Out:
#          CustomerId  Credit Score          Age        Tenure  \
# count  1.000100e+04  10001.000000  9998.000000  10001.000000
# mean   1.569093e+07    650.542946    38.920984      5.012699
# std    7.193531e+04     96.658818    10.489116      2.892047
# min    1.556570e+07    350.000000    18.000000      0.000000
# 25%    1.562852e+07    584.000000    32.000000      3.000000
# 50%    1.569073e+07    652.000000    37.000000      5.000000
# 75%    1.575323e+07    718.000000    44.000000      7.000000
# max    1.581569e+07    850.000000    92.000000     10.000000
#
#        Estimated Salary(€)
# count         10001.000000
# mean          99756.038763
# std           60583.962827
# min         -999999.000000
# 25%           50908.480000
# 50%          100183.050000
# 75%          149384.430000
# max          199992.480000
