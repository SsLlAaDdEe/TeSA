# %% [markdown]
# ## Control Flow
#
# ### Looping Statements (for, while)

# %% [raw]
# if #condition:
#     print(#command/result)
# elif #condition:
#     print(#command)
# else:
#     print(#command)

# %%
for i in range (1,71):
    if i % 5 == 0:
        print(f"{i} is divisible by 5")
    elif i % 7 == 0:
        print(f"{i} is divisible by 7")
else:
    print("Have a lovely day")
# Out:
# 5 is divisible by 5
# 7 is divisible by 7
# 10 is divisible by 5
# 14 is divisible by 7
# 15 is divisible by 5
# 20 is divisible by 5
# 21 is divisible by 7
# 25 is divisible by 5
# 28 is divisible by 7
# 30 is divisible by 5
# 35 is divisible by 5
# 40 is divisible by 5
# 42 is divisible by 7
# 45 is divisible by 5
# 49 is divisible by 7
# 50 is divisible by 5
# 55 is divisible by 5
# 56 is divisible by 7
# 60 is divisible by 5
# 63 is divisible by 7
# 65 is divisible by 5
# 70 is divisible by 5
# Have a lovely day

# %%
i = 1
while i < 71:
    if i % 5 == 0:
        print(f"{i} is divisible by 5")
    elif i % 7 == 0:
        print(f"{i} is divisible by 7")
    i += 1
# Out:
# 5 is divisible by 5
# 7 is divisible by 7
# 10 is divisible by 5
# 14 is divisible by 7
# 15 is divisible by 5
# 20 is divisible by 5
# 21 is divisible by 7
# 25 is divisible by 5
# 28 is divisible by 7
# 30 is divisible by 5
# 35 is divisible by 5
# 40 is divisible by 5
# 42 is divisible by 7
# 45 is divisible by 5
# 49 is divisible by 7
# 50 is divisible by 5
# 55 is divisible by 5
# 56 is divisible by 7
# 60 is divisible by 5
# 63 is divisible by 7
# 65 is divisible by 5
# 70 is divisible by 5

# %%
my_list = ['Seyi', 'Enjeghe', 'Kamara', 'Daniel', 'Tega']
name = 0
# Print "name is a TeSA student"
while name < len(my_list):
    print(f"{my_list[name]} is a TeSA student")
    name += 1
# Out:
# Seyi is a TeSA student
# Enjeghe is a TeSA student
# Kamara is a TeSA student
# Daniel is a TeSA student
# Tega is a TeSA student

# %%
for name in my_list:
    print(f"{name} is a TeSA student")
# Out:
# Seyi is a TeSA student
# Enjeghe is a TeSA student
# Kamara is a TeSA student
# Daniel is a TeSA student
# Tega is a TeSA student
