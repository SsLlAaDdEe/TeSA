# %% [markdown]
# ## Python

# %% [markdown]
# #### Loop Control Statements

# %% [markdown]
# ##### **Pass**

# %%
def student():
    pass

# %%
student()

# %%
def student_():
# Out:
#   Cell In[4], line 1
#     def student_():
#                    ^
# SyntaxError: incomplete input

# %%
for i in range(5):
    pass

# %%
for i in range(5):
    print (i**2)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
x = 7
if x > 5:
    pass
else:
    print("x is 5 or less")

# %%
x = 7
if x > 5:
    
else:
    print("x is 5 or less")
# Out:
#   Cell In[10], line 4
#     else:
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
x = 3
if x > 5:
    pass
else:
    print("x is 5 or less")
# Out:
# x is 5 or less

# %% [markdown]
# ##### **continue**

# %%
list(range(7))
# Out:
# [0, 1, 2, 3, 4, 5, 6]

# %%
for i in range(7):
    if i==2:
        continue
    print(i)
# Out:
# 0
# 1
# 3
# 4
# 5
# 6

# %%
for i in range(7):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
num = [-8, 0, 4, -1]

# %%
for i in num:
    if i < 0:
        continue
    print(i)
# Out:
# 0
# 4

# %%
name = ["Ade", "Shola", "Ayo", "Adeniyi", "Olaoluwa"]

# %%
for i in name:
    if i[0]=="A":
        continue
    print(i)
# Out:
# Shola
# Olaoluwa

# %%
x = 0
while x < 7:
    x += 1
    if x == 3:
        continue
    print(x)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7

# %%
x = 0
while x < 7:
    print(x)
    x += 1
    if x == 3:
        continue
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# ##### **break**

# %%
for i in range(7):
    if i==2:
        break
    print(i)
# Out:
# 0
# 1

# %%
num = [-8, 0, 4, -1]

# %%
for i in num:
    if i < 0:
        break
    print(i)

# %%
_num = [0, -8, 4, -1]

# %%
for i in _num:
    if i < 0:
        break
    print(i)
# Out:
# 0

# %%
x = 0
while x < 7:
    x += 1
    if x == 3:
        continue
    print(x)
# Out:
# 1
# 2
# 4
# 5
# 6
# 7

# %%
x = 0
while x < 7:
    if x == 3:
        x += 1
        continue
    print(x)
    x += 1
# Out:
# 0
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# equal to : ==
# assignment : =

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Built-in Functions
# * They are functions that are predefined in Python
# * It can be used without needing to import any library
# * You don't need to define they yourself
# * They are also Python's standard namespace i.e you can call them directly in your code

# %%
print()

# %%
print("Blessing is an Educator \nShe teaches Data Analytics")
# Out:
# Blessing is an Educator
# She teaches Data Analytics

# %% [markdown]
# * Arguments are values you pass into a function to call it

# %%
list(range())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 list(range())
#
# TypeError: range expected at least 1 argument, got 0

# %%
range()

# %%
"Blessing".
# Out:
# 2

# %%
x = [1,2,3,4,5]

# %%
x.append([5, 6])

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5, 1, 4, 5, 6, 7, [5, 6]]

# %%
x.extend([1,4,5])

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5, 1, 4, 5]

# %%
x.extend((6,7))

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5, 1, 4, 5, 6, 7]

# %%
x.extend(["Blessing", "Kamara"])

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5, 1, 4, 5, 6, 7, [5, 6], 'Blessing', 'Blessing', 'Kamara']

# %%
x.pop()
# Out:
# 'Kamara'

# %%
x.pop(-3)
# Out:
# [5, 6]

# %%
x
# Out:
# [1, 2, 3, 4, 5, 5, 1, 4, 5, 6, 7, 'Blessing', 'Blessing']

# %%
x.count('Blessing')
# Out:
# 2

# %%
x.pop()
# Out:
# 'Blessing'

# %%
x.sort()

# %%
x
# Out:
# [1, 1, 2, 3, 4, 4, 5, 5, 5, 6, 7]

# %%
x.sort(reverse=True)

# %%
x
# Out:
# [7, 6, 5, 5, 5, 4, 4, 3, 2, 1, 1]

# %%
x.pop(14)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 x.pop(14)
#
# IndexError: pop index out of range

# %% [markdown]
# #### User-defined Function

# %% [markdown]
# * Is a function that you create yourself
# * Using the def keyword

# %% [raw]
# def #function_name():
#     logic

# %%
def greeting():
    """
    This function is used to welcome a person!
    """
    print("Hello world!")

# %%
greeting()
# Out:
# Hello world!

# %%
greeting()
# Out:
# Hello world!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
greeting()
# Out:
# Hello world!

# %%
def add(value, value_, v):
    """
    This function takes in two numeric values and add them.
    """
    x = float(value) + float(value_) - float(v)
    print (int(x))

# %%
def add(value, value_, v):
    """
    This function takes in two numeric values and add them.
    """
    x = value + value_ - v
    print (int(x))

# %%
add(2, 9, 4)
# Out:
# 7

# %%
add (7.8, 3)
# Out:
# 10

# %%
print("""Hello
My name is
Blessing
""")
# Out:
# Hello
# My name is
# Blessing

# %%
print("Hello \nMy name is \nBlessing")
# Out:
# Hello
# My name is
# Blessing
